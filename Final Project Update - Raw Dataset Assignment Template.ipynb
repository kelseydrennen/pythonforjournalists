# %% [markdown]
# # Final Project Update - Raw Dataset Assignment Template

# %% [markdown]
# ## Dataset 1

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Dataset 2
#
# - This dataset came from GitHub
# - You can view the raw data from this link
# - [Dataset](https://github.com/b-mauldin/DataArts/blob/master/DataArts_BasicAttendance_Discipline.xlsx)
# - To me it looks like it seemed to me how many students in each state attended their arts classes and what the budget is.
# - It is kind of confusing, so I'm having a little bit of a hard time reading it.
# - The questions that I want to ask of this dataset is how much the budget was for Ohio and how many students attended the classes.
# - I'm hoping to get these answers and hopefully that'll show how many students don't do the arts as much anymore.
# - I have to see if this will be a valuable datasource so I will have to try and get in contact with the person that made the dataset.

# %%
import pandas as pd
df = pd.read_csv('data-arts-basic-attendance-discipline.csv')

# %%
df.head(10)
# Out:
#    organization_id header#fiscal_year_end_date State         Zip     County  \
# 0             8222                3/31/13 0:00    AB     T1L 1H5        NaN
# 1             8879                6/30/11 0:00    AB     T5J 4B2        NaN
# 2             9289                6/30/15 0:00    AB     T2R 1A5        NaN
# 3            19042                6/30/15 0:00    AK  99501-1812  Anchorage
# 4             9666                6/30/14 0:00    AL  35222-2407  Jefferson
# 5            18569               12/31/14 0:00    AL  35205-7011  Jefferson
# 6             9619                5/31/13 0:00    AL  36602-2719     Mobile
# 7            10934               12/31/15 0:00    AZ  85603-5317    Cochise
# 8            13048                6/30/11 0:00    AZ  85602-6620    Cochise
# 9            16409                5/31/14 0:00    AZ  85603-2743    Cochise
#
#    Paid Attendance In Person  Free Attendance In Person  \
# 0                       1024                        821
# ...

# %%
df.tail(10)
# Out:
#        organization_id header#fiscal_year_end_date State         Zip  \
# 11318            18603               12/31/14 0:00    WA  98684-4366
# 11319             4676               12/31/15 0:00    WA  98119-3253
# 11320             8117                6/30/14 0:00    WA  98109-5319
# 11321            18578               12/31/14 0:00    WA  98109-3504
# 11322             8539                5/31/11 0:00    WA  98402-4374
# 11323             9231                8/31/14 0:00    WI  53703-1702
# 11324            11482                6/30/14 0:00    WI  53719-1163
# 11325             8518                6/30/14 0:00    WI  53212-2212
# 11326             9506                6/30/09 0:00    WI  53202-6037
# 11327            18538               10/31/14 0:00    WY  82072-3459
#
#           County  Paid Attendance In Person  Free Attendance In Person  \
# 11318      Clark                          0                         82
# ...

# %%
df.shape
# Out:
# (11328, 11)
